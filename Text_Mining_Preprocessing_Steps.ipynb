# %% [markdown]
# <a href="https://colab.research.google.com/github/brahimje/DataMining/blob/main/Text_Mining_Preprocessing_Steps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# corpus of stopwords
import nltk
nltk.download('stopwords') # The stopwords list can be downloaded using the
from nltk.corpus import stopwords

stopwords_en = stopwords.words('english')
stopwords_ar = stopwords.words('arabic')
stopwords_fr = stopwords.words('french')

print("\n stopwords_en : \n", stopwords_en)
print("\n stopwords_ar : \n", stopwords_ar)
print("\n stopwords_fr : \n", stopwords_fr)
# Out:
#  stopwords_en :
# ...
